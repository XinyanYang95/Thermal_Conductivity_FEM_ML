# %%
import PIL
from PIL import Image
from matplotlib import image
from matplotlib import pyplot
import numpy as np

# %% [markdown]
# https://machinelearningmastery.com/how-to-load-and-manipulate-images-for-deep-learning-in-python-with-pil-pillow/

# %% [markdown]
# https://www.tensorflow.org/tutorials/keras/classification/

# %% [markdown]
# https://pytorch.org/tutorials/beginner/pytorch_with_examples.html

# %% [markdown]
# # Read

# %%
# load and display an image with Matplotlib
# load image as pixel array
data = image.imread('111.png')
# summarize shape of the pixel array
print(data.dtype)
print(data.shape)
# display the array of pixels as an image
pyplot.imshow(data)
pyplot.show()
# data
# Out:
# float32
# (224, 248, 3)

# %%
# load and display an image with Matplotlib
# load image as pixel array
data = image.imread('unscaled/mesh10_ktwo20_u.png')
# summarize shape of the pixel array
print(data.dtype)
print(data.shape)
# display the array of pixels as an image
pyplot.imshow(data)
pyplot.show()
# data
# Out:
# float32
# (224, 248, 3)

# %% [markdown]
# # Crop

# %%
thisimage = Image.open('111.png')
# create a cropped image
cropped = thisimage.crop((36, 24, 212, 200))
# cropped = image.crop((36, 24, 211, 200))
# show cropped image
# cropped.show()

# %%
data = np.array(cropped)

# %%
np.shape(cropped)
# Out:
# (176, 176)

# %%
len(list(range(36,212)))
# Out:
# 176

# %%
cropped
# Out:
# <PIL.Image.Image image mode=P size=176x176 at 0x1225C7C90>

# %%
np.shape(cropped)
# Out:
# (176, 178)

# %% [markdown]
# # Reszie

# %%
# # load the image
# image = Image.open('opera_house.jpg')
# report the size of the image
# print(cropped.size)
# resize image and ignore original aspect ratio
img_resized = cropped.resize((176,176))
# img_resized.save('unscaled/mesh30_ktwo10_u.png')

# %%
img_resized
# Out:
# <PIL.Image.Image image mode=P size=176x176 at 0x116CE1590>
